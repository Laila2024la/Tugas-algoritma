# %%
x_01 = int(input("input satu angka bilangan bulat :"))
x_01 = int(input("input satu angka bilangan bulat :"))
angka_prima = True
if((x_01 == 0) or (x_01 == 1)):
    angka_prima = false
else :
    for i in range (N) :
        start = 1000 * N
        end = 1000 * N + 1
if(angka_prima) :
    print(x,"adalah bilangan prima")
else :
    print(x,"bukan bilangan prima")
# Out:
# input satu angka bilangan bulat : 0
# input satu angka bilangan bulat : 1

# %%
print("0 bukan bilangan prima")
print("1 bukan bilangan prima")
# Out:
# 0 bukan bilangan prima
# 1 bukan bilangan prima
