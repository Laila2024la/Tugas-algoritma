# %%
FMIPA = ['Matematika','Fisika','Kimia','Biologi','Teknik informatika']
print(FMIPA)
# Out:
# ['Matematika', 'Fisika', 'Kimia', 'Biologi', 'Teknik informatika']

# %%
print(FMIPA[0])
# Out:
# Matematika

# %%
print(FMIPA[2])
# Out:
# Kimia

# %%
print(FMIPA[-1])
# Out:
# Farmasi

# %%
print(FMIPA[-2])
# Out:
# Biologi

# %%
FMIPA[0] = 'Farmasi'
print(FMIPA)
# Out:
# ['Farmasi', 'Fisika', 'Kimia', 'Biologi', 'Teknik informatika']

# %%
print(FMIPA[0:3])
# Out:
# ['Farmasi', 'Fisika', 'Kimia']

# %%
#tidak merubah list
print(FMIPA)
# Out:
# ['Farmasi', 'Fisika', 'Kimia', 'Biologi', 'Teknik informatika']

# %%
Alamat =['sapeken','sumenep','jawa timur']
Alamat.append('indonesia')
print(Alamat)
# Out:
# ['sapeken', 'sumenep', 'jawa timur', 'indonesia']

# %%
Alamat.insert(0,'kampung bukut')
print(Alamat)
# Out:
# ['kampung bukut', 'sapeken', 'sumenep', 'jawa timur', 'indonesia']

# %%
Alamat.remove('sumenep')
print(Alamat)
# Out:
# ['kampung bukut', 'sapeken', 'jawa timur', 'indonesia']

# %%
print('sumenep' in Alamat)
# Out:
# False

# %%
print('kampung bukut' in Alamat)
# Out:
# True

# %%
print(len(Alamat))
# Out:
# 4

# %%
hari =['senin','selasa','rabu','kamis','jumat','sabtu','minggu']
for jenis in hari:
    print(jenis)
# Out:
# senin
# selasa
# rabu
# kamis
# jumat
# sabtu
# minggu

# %%
i = 0
while i < len(hari):
    print(hari[i])
    i+=1
# Out:
# senin
# selasa
# rabu
# kamis
# jumat
# sabtu
# minggu
