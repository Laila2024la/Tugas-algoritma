# %%
FMIPA_01 = input('jurusan yang tersedia di FMIPA?')
jurusan_FMIPA_01 = []
for anggota in FMIPA_01:
    if anggota not in FMIPA_unik_01:
        jurusan_FMIPA_01.append(anggota)
print(jurusan_FMIPA_01)

# %%
for baris in bilangan_genap_01:
    print(bilangan_genap_01)

# %%
bilangan_ganjil_01 = (1,3,5,7,9,11,13,15)
for isi in bilangan_ganjil_01[1:15]:
    print(isi)

# %%
NIM_akhir_01 = input('masukan NIM akhir anda?')
NIM_akhir_01 = ''
for isi in NIM_akhir_01:
    NIM_akhir_01 += akhir.get(isi) + ' '
print(NIM_akhir_01)

# %%
data_diri_01 = input('list data diri mahasiswa?')
if data_diri_01.upper() == 'mahasiswa':
    nama_01 = float(input('siapakah nama anda?'))
    NIM_01 = float(input('berapa nim anda?'))
    prodi_01 = float(input('apa prodi anda?'))
    fakultas_01 = float(input('apa fakultas anda?'))
    print(data_diri_01)
