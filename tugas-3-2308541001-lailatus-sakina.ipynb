# %%
harga = float(input("harga barang anda adalah "))
if harga >= 90:
    print("harga barang yang paling mahal")
    print("kualitas bagus, selamat!")
if harga < 90 and harga >= 70:
    print("harga barang yang standar")
    print("kualitas lumayan bagus")
if harga >= 50 and harga < 70:
    print("harga barang yang murah")
    print("kualitas jelek")
# Out:
# harga barang anda adalah  100
# harga barang yang paling mahal
# kualitas bagus, selamat!

# %%
a = 40
while a < 100:
    print("berat badan " + str(a)+" masih di bawah 100")
    a += 10
# Out:
# berat badan 40 masih di bawah 100
# berat badan 50 masih di bawah 100
# berat badan 60 masih di bawah 100
# berat badan 70 masih di bawah 100
# berat badan 80 masih di bawah 100
# berat badan 90 masih di bawah 100
