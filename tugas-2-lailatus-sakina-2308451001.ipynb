# %%
nilai_IP_semester = input("Berapakah nilai IP semester anda? ")
nilai_IP_kumulatif = input("Berapakah nilai IP kumulatif anda? ")
print("Total nilai anda adalah " + nilai_IP_semester + nilai_IP_kumulatif)
# Out:
# Berapakah nilai IP semester anda?  3,25
# Berapakah nilai IP kumulatif anda?  3,15
# Total nilai anda adalah 3,253,15

# %%
nama = 'Lailatus sakina'
gelar = 'sarjana matematika'
institut = 'universitas udayana'
tahun = '2023'
print(nama + 'adalah seorang mahasiswa' + gelar + 'di' + institut + 'angkatan' + tahun + '.')
# Out:
# Lailatus sakinaadalah seorang mahasiswasarjana matematikadiuniversitas udayanaangkatan2023.

# %%
hari = 'selasa,26 maret 2024'
print(hari)
# Out:
# selasa,26 maret 2024

# %%
alamat = 'jl dr goris,gang tehnik 2 no 14,denpasar timur'
print(alamat)
# Out:
# jl dr goris,gang tehnik 2 no 14,denpasar timur

# %%
print(4+5)
print(4-5)
print(4*5)
print(9/5)
print(9//5)
print(9%5)
print(4**5)
X=5
X+=1
print(X)
X=-4
print(X)
X*=5
print(X)
# Out:
# 9
# -1
# 20
# 1.8
# 1
# 4
# 1024
# 6
# -4
# -20

# %%
X = 7>6
print(X)
X = 6<7
print(X)
X = 7 >=2
print(X)
X = 2 <=7
print(X)
X = 7 ==7
print(X)
X = 3 !=8
print(X)
# Out:
# True
# True
# True
# True
# True
# True

# %%
baju = 12
celana = 10
print(baju > 10 and celana < 15)
# Out:
# True
