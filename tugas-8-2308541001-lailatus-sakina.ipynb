# %%
# Membuat program persamaan garis di pyton berdasarkan 3 kondisi
# 1. Diketahui dua titik
# 2. Diketahui 1 gradien dan 1 titik yang dilewati
# 3. Diketahui persamaan ax + by = c

import numpy as np
import matplotlib.pyplot as plt

def __init__(self):
    pass
def dari_dua_titik(self, x1, y1,x2, y2):
    if x1 == x2:
        raise ValueError("kedua titik memiliki nilai x yang sama, ini merupakan garis vertikal.")
    m_01 = (y2 - y1) / (x2 - x1)
    c_01 = y1 - m * x1
    return m, c

def dari_titik_dan_gradien(self, m, x, y):
    c_01 = y - m * x
    return m, c
def dari_persamaan_ax_by_c(self, a, b, c):
    if b == 0:
        raise ValueError("b tidak boleh nol untuk menghindari pembagian dengan nol.")
        m_01 = -a / b
        c_01 = c / b
        return m, c
def tampilkan_persamaan(self, m, c):
        return f"y = {m}x + {c}"
def main():
        pg = persamaanGaris()
        
        # kondisi 1: Diketahui dua titik
        x1, y1_01 = 1, 2
        x2, y2_01 = 3, 4
        m, c_01 = pg.dari_dua_titik(x1,y1,x2,y2)
        print("persamaan dari dua titik:", 
              pg.tampilkan_persamaan(m, c))
        
        # kondisi 2: Diketahui 1 gradien dan 1 titik yang dilewati
        m_01= 2
        x, y1_01 = 1, 2
        m, c_01 = pg.dari_titik_dan_gradien(m,x,y)
        print("persamaan dari gradien dan 1 titik:", 
              pg.tampilkan_persamaan(m, c))
        
        # kondisi 3: Diketahui persamaan ax + by = c
        a. b, c_value_01 = 1,-2.3
        m, c_01 = pg.dari_persamaan_ax_by_c(a, b, c_value)
        print("persamaan dari bentuk ax + by = c:", 
              pg.tampilkan_persamaan(m, c))
        
        if __name__ == "__main__":
            main()

# %%
import matplotlib.pyplot as plt
# Data untuk plot pertama
x = np.linspace(-2,2,1000)
x = 1.3 
# Data untuk plot kedua
y = 2.4
fig, ax = plt.subplots()
line1 = ax.plot(x, y, c="y", label='plot 1: x = 1.3')
line2 = ax.plot(x, y, c="c", label='plot 2: y = 2.4')
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
ax.set_title("persamaan garis")
ax.legend()
plt.show()
