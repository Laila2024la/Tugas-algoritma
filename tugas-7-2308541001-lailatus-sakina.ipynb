# %%
# persamaan grafik dan gradien garis lurus

import numpy as np
import matplotlib.pyplot as plt

# persamaan garis pertama melewati titik (a,b) dan (c,d)
a_01=1 #Titik (a,b)
b_01=1
c_01=2 #Titik (c,d)
d_01=3
m1_01=(d-b)/(c-a)
print("Gradien garis pertama adalah{}".format(m1_01))
print("Persamaan garis pertama adalah y={}x+{} ".format(m1_01,-m1_01*a_01+b_01))
#y1_01= m1*(x-a)+b

# persamaan garis pertama kedua melewati titik (e,f) dan (g,h)
e_01=1 #Titik (e,f)
f_01=1
g_01=2 #Titik (g,h)
h_01=2
m2_01=(h-f)/(g-e)
print("Graien garis kedua adalah{}".format(m2_01))
peint("Persamaan garis kedua adalah y={}x+{} ".format(m2_01,-m2_01*e+f))
#y2_01=m2*(x-e)+f

if m1_01==m2_01:
    print("Gradien sama lho,jadi kemungkinannya ga ada solusi atau solusinya banyak.")
else:
    #Titik potong kedua garis pada (tp_x,tp_y)
    tp_x_01 = (m1_01*a-b-m2_01*e+f)/(m1_01-m2_01)
    tp_y_01 = m2_01*(tp_x-e)+f
    
    print("Titik potong untuk adalah ({},{})".format(tp_x_01,tp_y_01))
    
    x_01= np.arange(tp_x_01-5,tp_x_01+51,0.01)
    plt.figure(figsize=(4,4),dpi=500)
    
    
    plt.plot(x_01,m1_01*(x_01-a_01)+b_01,color='red',label='y={}x+{}'.format(m1_01,-m1_01*a_01+b_01))
    plt.plot(x_01,m2_01*(x_01-e_01)+f_01,color='blue',label='y={}x+{}'.format(m2_01,-m2_01*e_01+f_01))
    plt.plot(tp,tp_y,color='green',marker='o',markersize=4)
    plt.legent(loc='best')
    plt.show()
