# %%
# masukkan nilai x antara x_1 = 0.6180339887498949 atau x_2 = -1.618033988749895
x=float(input("Nilai x adalah "))

if x>0:
    print("Nilai n adalah {}".format(SMA_positif(x)))
else:
    print("Nilai n adalah {}".format(SMA_negatif(x)))
# Out:
# Nilai x adalah  -1.618033988749895

# %%
# membuktikan nilai n antara n_1 = 2024 apakah sama dengan n_2 = 675.3333333333334
n_01=float(input("Nilai n adalah"))

if n_1_01 == n_2_01:
    print("n1 sama dengan n_2")
else:
    print("n1 tidak sama dengan n2")
# Out:
# Nilai n adalah 675.3333333333334
